# %% [markdown]
# ### 5 Insights and a Visualization
# I produced 5 insights and a visualization from the twitter_archive_master.csv dataset. I would take time here and look in detail what each insight
# mean.

# %% [markdown]
# #### Insight 1

# %% [markdown]
# ##### Doggo dogs are the most retweeted

# %% [markdown]
# Some people retweet things they find insightful, entertaining and many more. A person might retweet a dog because he/she might find the dog attractive. The challenge with the dog_stage column is that a huge proportion of the dogs tweeted could not be classified. Nonetheless, working with the number of dogs which were able to be classified showed that doggo dogs were the most retweeted dogs followed closely by pupper, and then puppo and the last been floofer. The image below depicts this insight

# %% [markdown]
# ![12-2.PNG](attachment:12-2.PNG)

# %% [markdown]
# #### Insight 2

# %% [markdown]
# ##### Most tweets were from iphone users

# %% [markdown]
# Its amazing the continues dominance of apple products in the world's digital space. This is confirmed by this dataset with almost all of tweets been done from iphones. Lets see in years to come if any player in the tech industry can break their dominance. The picture below supports the claim made from this insight

# %% [markdown]
# ![13-2.PNG](attachment:13-2.PNG)

# %% [markdown]
# #### Insight 3

# %% [markdown]
# ##### Doggo dogs were the most highly rated dogs

# %% [markdown]
# Interestingly, pupper dogs top our chart for the highly rated dog stage. Maybe people indeed love these dogs. It will be interesting to see the change that will occur if majority of dogs were to be classified. Will pupper dogs still be highly rated?

# %% [markdown]
# ![14-2.PNG](attachment:14-2.PNG)

# %% [markdown]
# #### Insight 4

# %% [markdown]
# ##### A doggo dog received the most retweets

# %% [markdown]
# A doggo received the higest number of retweets at a whooping 79515 retweets. Maybe people indeed love these dogs

# %% [markdown]
# ![15.PNG](attachment:15.PNG)

# %% [markdown]
# The first line of code returns the highest retweet value. The second line of code return the dog_stage with thatthe highest retweets. And there we have our confirmation A DOGGO!!!!

# %% [markdown]
# Insight 5

# %% [markdown]
# ##### The numerator value of 13 was the most retweeted

# %% [markdown]
# With this insight we did two things. First we found an insight and then we backed our insight with somw visualization. We looked out for the rating with the highest number of retweets. We can confirm that dogs who receive a rating of 1.3 or 13/10 was the most retweeted. Below is our visualization to back this claim.

# %% [markdown]
# ![last-2.PNG](attachment:last-2.PNG)
